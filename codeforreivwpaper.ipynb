# %% [markdown]
# <a href="https://colab.research.google.com/github/armanut86/arman/blob/master/codeforreivwpaper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code for the review paper figures!

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
from array import array

# %%
dre=pd.read_excel(open('review.xlsx','rb'),sheet_name='DR',header=1)
dre

# %%
dre['year']

# %%
plt.plot(dre['year'])
